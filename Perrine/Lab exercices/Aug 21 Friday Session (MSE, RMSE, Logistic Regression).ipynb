# %% [markdown]
# - Data Visualization
# - MSE vs RMSE
# - Logistic and Linear Regression

# %% [markdown]
# Type 1 Error (False Positive Error)
# - When null hypothesis is TRUE, but we reject the it
#
#
# Type 2 Error (False Negative Error)
# - When null hypothesis is FALSE, but we fail to reject it
#
# Example Null Hypothesis -
# 1. Person A is not guilty of the crime
# 2. Medicine A cures disease B
# 3. Ad A is effective in driving conversions

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
actual_y = [1, 2, 3, 4, 5, 6, 7, 8, 9]

model_1_predictions = [1, 2.5, 3.2, 5, 4, 7, 7.5, 8.8, 10]
model_2_predictions = [1, 2.5, 3.2, 5, 4, 11, 7.5, 8.8, 10]

# %%
fig, ax = plt.subplots(1,2, figsize=(15,5))

ax[0].scatter(actual_y, model_1_predictions)
ax[0].set_title("Actual Y vs Model 1 Predictions")
ax[0].set_xlabel("Actual")
ax[0].set_ylabel("Predicted")
ax[0].plot([1,10], [1,10])

ax[1].scatter(actual_y, model_2_predictions)
ax[1].set_title("Actual Y vs Model 2 Predictions")
ax[1].set_xlabel("Actual")
ax[1].set_ylabel("Predicted")
ax[1].plot([1,10], [1,10])

plt.show()

# %%
actual_y
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
model_1_predictions
# Out:
# [1, 2.5, 3.2, 5, 4, 7, 7.5, 8.8, 10]

# %%
model_2_predictions
# Out:
# [1, 2.5, 3.2, 5, 4, 11, 7.5, 8.8, 10]

# %%
from sklearn.metrics import mean_squared_error

np.sqrt(mean_squared_error(actual_y, model_1_predictions))
# Out:
# 0.758653778449403

# %%
mse_1 = mean_squared_error(actual_y, model_1_predictions)
rmse_1 = np.sqrt(mse_1)

mse_2 = mean_squared_error(actual_y, model_2_predictions)
rmse_2 = np.sqrt(mse_2)

mae_1 = mean_absolute_error(actual_y, model_1_predictions)
mae_2 = mean_absolute_error(actual_y, model_2_predictions)

# %%
fig, ax = plt.subplots(1, figsize=(8,5))

ax.bar(["RMSE 1", "RMSE 2", "MSE 1", "MSE 2", "MAE 1", "MAE 2"], [rmse_1, rmse_2, mse_1, mse_2, mae_1, mae_2])
ax.set_title("Cmparing MSE and RMSE")
ax.set_xlabel("Metric")
ax.set_ylabel("Value")

plt.show()

# %%
print("Root Mean Squared Error for Model 1 = %.2f"%rmse_1)
print("Root Mean Squared Error for Model 2 = %.2f"%rmse_2)
# Out:
# Root Mean Squared Error for Model 1 = 0.76
# Root Mean Squared Error for Model 2 = 1.80

# %%
print("Mean Squared Error for Model 1 = %.2f"%mse_1)
print("Mean Squared Error for Model 2 = %.2f"%mse_2)
# Out:
# Mean Squared Error for Model 1 = 0.58
# Mean Squared Error for Model 2 = 3.24

# %%
model_3_predictions = [1,2,3,4,5,6,7,8,12]

fig, ax = plt.subplots(1,3, figsize=(20,5))

ax[0].scatter(actual_y, model_1_predictions)
ax[0].set_title("Model 1 Predictions")
ax[0].set_xlabel("Actual")
ax[0].set_ylabel("Predicted")
ax[0].plot([1,10], [1,10])

ax[1].scatter(actual_y, model_2_predictions)
ax[1].set_title("Model 2 Predictions")
ax[1].set_xlabel("Actual")
ax[1].set_ylabel("Predicted")
ax[1].plot([1,10], [1,10])

ax[2].scatter(actual_y, model_3_predictions)
ax[2].set_title("Model 3 Predictions")
ax[2].set_xlabel("Actual")
ax[2].set_ylabel("Predicted")
ax[2].plot([1,10], [1,10])

plt.show()

# %%
mse_1 = mean_squared_error(actual_y, model_1_predictions)
rmse_1 = np.sqrt(mse_1)

mse_2 = mean_squared_error(actual_y, model_2_predictions)
rmse_2 = np.sqrt(mse_2)

mse_3 = mean_squared_error(actual_y, model_3_predictions)
rmse_3 = np.sqrt(mse_3)

fig, ax = plt.subplots(1, figsize=(8,5))

labels = ["RMSE 1", "RMSE 2", "RMSE 3", "MSE 1", "MSE 2", "MSE 3"]
values = [rmse_1, rmse_2, rmse_3, mse_1, mse_2, mse_3]
ax.bar(labels, values)
ax.set_title("Comparing MSE and RMSE")
ax.set_xlabel("Metric")
ax.set_ylabel("Value")

plt.show()

# %%
print("Root Mean Squared Error for Model 1 = %.2f"%rmse_1)
print("Root Mean Squared Error for Model 2 = %.2f"%rmse_2)
print("Root Mean Squared Error for Model 3 = %.2f"%rmse_3)
# Out:
# Root Mean Squared Error for Model 1 = 0.76
# Root Mean Squared Error for Model 2 = 1.80
# Root Mean Squared Error for Model 3 = 1.00

# %%
print("Mean Squared Error for Model 1 = %.2f"%mse_1)
print("Mean Squared Error for Model 2 = %.2f"%mse_2)
print("Mean Squared Error for Model 3 = %.2f"%mse_3)
# Out:
# Mean Squared Error for Model 1 = 0.58
# Mean Squared Error for Model 2 = 3.24
# Mean Squared Error for Model 3 = 1.00

# %% [markdown]
# ### Logistic regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import mean_squared_error, mean_absolute_error

from sklearn.linear_model import LogisticRegression

# %%
data = pd.read_csv("Labs/dat/titanic.csv")
data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-30-bab740f7b836> in <module>
# ----> 1 data = pd.read_csv("Labs/dat/titanic.csv")
#       2 data.head()
#
# ~\anaconda3\envs\python 37\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
# data.drop(['PassengerId', 'Cabin'], axis=1)

# Use numerical columns for logistic regression
df = data[['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']]
df = df.dropna()

# %% [markdown]
# #### Machine Learning Skeleton
#
# #### Define Input and target features
# X
#
# y
#
# #### Train Test split
# X_train, X_test, y_train, y_test
#
# #### Create model
# model
#
# #### Train model
# model.fit()
#
# #### Make predictions
# y_pred
#
# #### Evaluate model
# model.score()

# %%
# df.drop('Survived', axis=1)

# %%
# Define Input and target features
X = df.drop('Survived', axis=1)
y = df['Survived']

# Train Test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# Create model
model = LogisticRegression()

# Train model
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Evaluate model
model.score(X_test, y_test)
# Out:
# 0.6805555555555556

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

accuracy_score(y_test, y_pred) * 100

# %%
# Confusion Matrix Orientation in Sklearn   
    
             Prediction

Actual         TN FP
               FN TP

# %%
y_pred_train = model.predict(X_train)

confusion_matrix(y_pred_train, y_pred_train)
# Out:
# array([[448,   0],
#        [  0, 194]], dtype=int64)
