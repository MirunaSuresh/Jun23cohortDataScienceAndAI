# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Data
#
# > The sinking of the RMS Titanic is one of the most infamous shipwrecks in history.  On April 15, 1912, during her maiden voyage, the Titanic sank after colliding with an iceberg, killing 1502 out of 2224 passengers and crew. This sensational tragedy shocked the international community and led to better safety regulations for ships.
#
# > One of the reasons that the shipwreck led to such loss of life was that there were not enough lifeboats for the passengers and crew. Although there was some element of luck involved in surviving the sinking, some groups of people were more likely to survive than others, such as women, children, and the upper-class.
#
# In this lab, we'll explore this dataset to find insight.
#
# [Titanic Dataset](https://www.kaggle.com/c/titanic/data)

# %% [markdown]
# # Data Dictionary
#
# | Variable |                                 Definition | Key                                            |
# |----------|-------------------------------------------:|------------------------------------------------|
# | Survival | Survival                                   | 0 = No, 1 = Yes                                |
# | Pclass   | Ticket class                               | 1 = 1st, 2 = 2nd, 3 = 3rd                      |
# | Sex      | Sex                                        |                                                |
# | Age      | Age in years                               |                                                |
# | SibSp    | # of siblings / spouses aboard the Titanic |                                                |
# | Parch    | # of parents / children aboard the Titanic |                                                |
# | Ticket   | Ticket number                              |                                                |
# | Fare     | Passenger fare                             |                                                |
# | Cabin    | Cabin number                               |                                                |
# | Embarked | Port of Embarkation                        | C = Cherbourg, Q = Queenstown, S = Southampton |

# %% [markdown]
# # Loading Modules

# %%
# Load necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Loading Dataset
#
# Read titanic dataset.

# %%
# Read Titanic Dataset
titanic_csv = 'titanic.csv'
titanic = pd.read_csv(titanic_csv)

# %% [markdown]
# # Explore Dataset

# %% [markdown]
# ## Head

# %%
# Check Head
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Tail

# %%
# Check Tail
titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# ## Shape
#
# Find shape of dataset.

# %%
# ANSWER
titanic.shape
# Out:
# (891, 12)

# %% [markdown]
# ## Check Types of Data
#
# Check types of data you have

# %%
# ANSWER
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ## Check Null Values
#
# Check whether dataset have any null values.

# %%
# ANSWER
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Check titanic data again
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Fill Null Values
#
# Is there any null values in any columns?
#
# - Identify those columns
# - Fill those null values using your own logic
#     - State your logic behind every steps

# %% [markdown]
# ### Age

# %%
# ANSWER - replacing with mean not to skew or lose data too much as we have 177 missing out of 891.
titanic['Age'].fillna((titanic['Age'].mean()))
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
# 5      29.699118
# 6      54.000000
# 7       2.000000
# 8      27.000000
# 9      14.000000
# 10      4.000000
# 11     58.000000
# 12     20.000000
# 13     39.000000
# 14     14.000000
# 15     55.000000
# 16      2.000000
# 17     29.699118
# 18     31.000000
# 19     29.699118
# 20     35.000000
# 21     34.000000
# 22     15.000000
# 23     28.000000
# 24      8.000000
# 25     38.000000
# 26     29.699118
# 27     19.000000
# 28     29.699118
# 29     29.699118
#          ...
# 861    21.000000
# 862    48.000000
# 863    29.699118
# 864    24.000000
# 865    42.000000
# 866    27.000000
# 867    31.000000
# 868    29.699118
# 869     4.000000
# 870    26.000000
# 871    47.000000
# 872    33.000000
# 873    47.000000
# 874    28.000000
# 875    15.000000
# 876    20.000000
# 877    19.000000
# 878    29.699118
# 879    56.000000
# 880    25.000000
# 881    33.000000
# ...

# %% [markdown]
# ### Cabin

# %%
# ANSWER - replacing with 'missing' to make it clear as it's a an object column so we can have text and we aren't messing with the data as there are 687 missing values
titanic['Cabin'].fillna('missing')
# Out:
# 0          missing
# 1              C85
# 2          missing
# 3             C123
# 4          missing
# 5          missing
# 6              E46
# 7          missing
# 8          missing
# 9          missing
# 10              G6
# 11            C103
# 12         missing
# 13         missing
# 14         missing
# 15         missing
# 16         missing
# 17         missing
# 18         missing
# 19         missing
# 20         missing
# 21             D56
# 22         missing
# 23              A6
# 24         missing
# 25         missing
# 26         missing
# 27     C23 C25 C27
# 28         missing
# 29         missing
#           ...
# 861        missing
# 862            D17
# 863        missing
# 864        missing
# 865        missing
# 866        missing
# 867            A24
# 868        missing
# 869        missing
# 870        missing
# 871            D35
# 872    B51 B53 B55
# 873        missing
# 874        missing
# 875        missing
# 876        missing
# ...

# %% [markdown]
# Embarked

# %%
# Answer - replacing with nearest value as only 2 missing
titanic['Embarked'].fillna(method='ffill')
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
# 5      Q
# 6      S
# 7      S
# 8      S
# 9      C
# 10     S
# 11     S
# 12     S
# 13     S
# 14     S
# 15     S
# 16     Q
# 17     S
# 18     S
# 19     C
# 20     S
# 21     S
# 22     Q
# 23     S
# 24     S
# 25     S
# 26     C
# 27     S
# 28     Q
# 29     S
#       ..
# 861    S
# 862    S
# 863    S
# 864    S
# 865    S
# 866    C
# 867    S
# 868    S
# 869    S
# 870    S
# 871    S
# 872    S
# 873    S
# 874    C
# 875    C
# 876    S
# 877    S
# 878    S
# 879    C
# 880    S
# 881    S
# 882    S
# 883    S
# 884    S
# 885    Q
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
titanic.sample(20)
# Out:
#      PassengerId  Survived  Pclass  \
# 380          381         1       1
# 649          650         1       3
# 590          591         0       3
# 404          405         0       3
# 372          373         0       3
# 446          447         1       2
# 397          398         0       2
# 499          500         0       3
# 278          279         0       3
# 14            15         0       3
# 486          487         1       1
# 732          733         0       2
# 61            62         1       1
# 249          250         0       2
# 784          785         0       3
# 630          631         1       1
# 237          238         1       2
# 733          734         0       2
# 585          586         1       1
# 500          501         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 380                            Bidois, Miss. Rosalie  female  42.0      0
# ...

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic.fillna(method='ffill')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %% [markdown]
# # Describe
#
# Describe your dataset.

# %%
# ANSWER
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # Relationship between Features and Survival
#
# Find relationship between categorical features and survived.
#
# **Describe your findings.**

# %%
def bar_charts(df, feature):
    '''
    Inputs:
    df: Dataset
    feature: Name of Feature to Check With Survived
    '''
    _agg = {
        'PassengerId': 'count'
    }
    _groupby = ['Survived', feature]

    df_feature = df.groupby(by=_groupby).agg(_agg)
    
    ax = df_feature.unstack().plot(kind='bar', figsize=(15,6))
    plt.legend(list(df_feature.index.levels[1].unique()))
    plt.xlabel('Survived')
    plt.xticks(np.arange(2), ('No', 'Yes'))
    plt.show();

# %% [markdown]
# ## Pclass
#
# Use barchart to find relationship between survived and pclass.  Note your findings.

# %%
# ANSWER
bar_charts(titanic, 'Pclass')
# OVer 60% of deaths are from class 3 and class 1 had the highest number of survivors.

# %% [markdown]
# ## Sex
#
# Use barchart to find relationship between survived and sex.  Note your findings.

# %%
# ANSWER
bar_charts(titanic, 'Sex')
# Over 85% of deaths are male and male also represents around only 30% of survivors

# %% [markdown]
# ## Parch
#
# Parch = Number of parents of children travelling with each passenger.

# %%
# ANSWER
bar_charts(titanic, 'Parch')
# parents with children had a higher chance of surviving

# %% [markdown]
# ## SibSp

# %%
# of siblings / spouses aboard the Titanic	
bar_charts(titanic, 'SibSp')
# Passenger with at least one sibling/spouse had a higher chance of surviving

# %% [markdown]
# ## Embarked

# %%
# of siblings / spouses aboard the Titanic	
bar_charts(titanic, 'Embarked')
# passengers who embarked from Cherbourg port had a higher chance of surviving

# %% [markdown]
# # Feature Engineering
#
# Create some new features from existing feature.

# %% [markdown]
# ## Fare Class
#
# Create a new class based on their fare. Is there any relationship between fare and survival?

# %%
def create_fare_class(x):
    if x > 30:
        fare_class = 1
    elif x > 20 and x <= 30:
        fare_class = 2
    elif x > 10 and x <= 20:
        fare_class = 3
    else:
        fare_class = 4
    return fare_class

# %%
# ANSWER
fare_class = titanic.append(fare_class)
bar_charts(titanic, 'fare_class')
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-84-722964564d31> in <module>()
#       1 # ANSWER
# ----> 2 fare_class = titanic.append(fare_class)
#       3 bar_charts(titanic, 'fare_class')
#
# NameError: name 'fare_class' is not defined

# %% [markdown]
# ## Age Class

# %%
# ANSWER

# %%
def create_age_class(x):
    if x > 60:
        age_class = 5
    elif x > 35 and x <= 60:
        age_class = 4
    elif x > 25 and x <= 35:
        age_class = 3
    elif x > 16 and x <= 25:
        age_class = 2
    else:
        age_class = 1
    return age_class

# %%
# ANSWER
age_class = titanic.append(age_class)
bar_charts(titanic, 'age_class')
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-83-66b862bfe0ff> in <module>()
#       1 # ANSWER
# ----> 2 age_class = titanic.append(age_class)
#       3 bar_charts(titanic, 'age_class')
#
# NameError: name 'age_class' is not defined

# %% [markdown]
# # Staistical Overview

# %% [markdown]
# ## Correlation
#
# Find correlation between `survived` and other features.

# %%
titanic.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %% [markdown]
# # [BONUS] Hypothesis Testing
# ---
# Hypothesis testing is the use of statistics to determine the probability that a given hypothesis is true. The usual process of hypothesis testing consists of four steps.
#
# 1. Formulate the null hypothesis H_0 (commonly, that the observations are the result of pure chance) and the alternative hypothesis H_a (commonly, that the observations show a real effect combined with a component of chance variation).
#
# 2. Identify a test statistic that can be used to assess the truth of the null hypothesis.
#
# 3. Compute the P-value, which is the probability that a test statistic at least as significant as the one observed would be obtained assuming that the null hypothesis were true. The smaller the P-value, the stronger the evidence against the null hypothesis.
#
# 4. Compare the p-value to an acceptable significance value  alpha (sometimes called an alpha value). If p<=alpha, that the observed effect is statistically significant, the null hypothesis is ruled out, and the alternative hypothesis is valid.

# %% [markdown]
# ### Define Hypothesis
#
# > Formulate the null hypothesis H_0 (commonly, that the observations are the result of pure chance) and the alternative hypothesis H_a (commonly, that the observations show a real effect combined with a component of chance variation).
#
#     Null Hypothesis (H0): There is no difference in the survival rate between the young and old passengers.
#
#     Alternative Hypothesis (HA): There is a difference in the survival rate between the young and old passengers.

# %% [markdown]
# ### Collect Data
#
# Next step is to collect data for each population group.
#
# Collect two sets of data, one with the passenger greater than 35 years of age and another one with the passenger younger than 35. The sample size should ideally be the same but it can be different. Lets say that the sample sizes is 100.

# %%
# ANSWER
titanic_young = titanic[titanic['Age'] <= 35]
titanic_old = titanic[titanic['Age'] > 35]

# %% [markdown]
# ### Set alpha (Let alpha = 0.05)
#
# > Identify a test statistic that can be used to assess the truth of the null hypothesis.

# %%
# ANSWER

# %% [markdown]
# ### Calculate point estimate

# %%
a = titanic_young['Survived']
b = titanic_old['Survived']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-29264cd31654> in <module>
# ----> 1 a = titanic_young['Survived']
#       2 b = titanic_old['Survived']
#
# NameError: name 'titanic_young' is not defined

# %%
## Calculate the variance to get the standard deviation
var_a = a.var()
var_b = b.var()

## Calculate the Standard Deviation
s = np.sqrt((var_a + var_b)/2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-d8f593a782c8> in <module>
#       1 ## Calculate the variance to get the standard deviation
# ----> 2 var_a = a.var()
#       3 var_b = b.var()
#       4
#       5 ## Calculate the Standard Deviation
#
# NameError: name 'a' is not defined

# %% [markdown]
# ### Calculate test statistic

# %%
## Calculate the t-statistics
t = (a.mean() - b.mean())/(s*np.sqrt(2/N))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-4cc4dca8c6cf> in <module>
#       1 ## Calculate the t-statistics
# ----> 2 t = (a.mean() - b.mean())/(s*np.sqrt(2/N))
#
# NameError: name 'a' is not defined

# %% [markdown]
# ### Find the p-value
#
# > Compute the P-value, which is the probability that a test statistic at least as significant as the one observed would be obtained assuming that the null hypothesis were true. The smaller the P-value, the stronger the evidence against the null hypothesis.

# %%
## Compare with the critical t-value
## Degrees of freedom
df = 2*N - 2

#p-value after comparison with the t 
p = 1 - stats.t.cdf(t,df=df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-c8da0937c8b3> in <module>
#       1 ## Compare with the critical t-value
#       2 ## Degrees of freedom
# ----> 3 df = 2*N - 2
#       4
#       5 #p-value after comparison with the t
#
# NameError: name 'N' is not defined

# %%
print("t = " + str(t))
print("p = " + str(2*p))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-23d5a09e55a3> in <module>
# ----> 1 print("t = " + str(t))
#       2 print("p = " + str(2*p))
#
# NameError: name 't' is not defined

# %% [markdown]
# ### Interpret results
#
# > Compare the p-value to an acceptable significance value  alpha (sometimes called an alpha value). If p<=alpha, that the observed effect is statistically significant, the null hypothesis is ruled out, and the alternative hypothesis is valid.

# %%
def print_sig(p_value, alpha):
    if p_value < alpha:
        print("We reject our null hypothesis.")
    elif p_value > alpha:
        print("We fail to reject our null hypothesis.")
    else:
        print("Our test is inconclusive.")

# %%
## Cross Checking with the internal scipy function
t2, p2 = stats.ttest_ind(a,b)
print("t = " + str(t2))
print("p = " + str(p2))

print_sig(p2, alpha)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-20d772deacf0> in <module>
#       1 ## Cross Checking with the internal scipy function
# ----> 2 t2, p2 = stats.ttest_ind(a,b)
#       3 print("t = " + str(t2))
#       4 print("p = " + str(p2))
#       5
#
# NameError: name 'stats' is not defined

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2019 Institute of Data
#
#
# ---
#
#
#
# ---
