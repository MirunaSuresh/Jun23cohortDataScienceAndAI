# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Numpy Exploration

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# get matplot to show charts inline
# %matplotlib inline

# %%
height= np.round(np.random.normal(1.75, 0.20, 7000), 2)
weight= np.round(np.random.normal(60.32, 15, 7000), 2)
population=np.column_stack((height, weight))

# %%
print('height:\n',height)
print('weight:\n',weight)
print('population:\n',population)
# Out:
# height:
#  [1.9  1.56 1.56 ... 1.68 1.69 1.76]
# weight:
#  [63.71 28.   66.58 ... 70.   31.78 73.79]
# population:
#  [[ 1.9  63.71]
#  [ 1.56 28.  ]
#  [ 1.56 66.58]
#  ...
#  [ 1.68 70.  ]
#  [ 1.69 31.78]
#  [ 1.76 73.79]]

# %% [markdown]
# **1. Find Dimension of Array**
#
# Find dimention of each array: height, weight, population
# ```
# # Expected Ouput
# np.ndim(height): 1
# np.ndim(weight): 1
# np.ndim(population): 2
# ```

# %%
np.ndim(height)
# Out:
# 1

# %%
np.ndim(weight)
# Out:
# 1

# %%
np.ndim(population)
# Out:
# 2

# %% [markdown]
# **2. Find Shape of Array**
#
# Find shape of each array: height, weight, population
# ```
# # Expected Ouput
# np.shape(height) : (7000,)
# np.shape(weight) : (7000,)
# np.shape(population) : (7000, 2)
# ```

# %%
np.shape(height)
# Out:
# (7000,)

# %%
np.shape(weight)
# Out:
# (7000,)

# %%
np.shape(population)
# Out:
# (7000, 2)

# %% [markdown]
# **3. Find Size of Array**
#
# Find shape of each array: height, weight, population
# ```
# # Expected Ouput:
# np.size(height) : 7000
# np.size(weight) : 7000
# np.size(weight) : 14000
# ```

# %%
np.size(height)
# Out:
# 7000

# %%
np.size(weight)
# Out:
# 7000

# %%
np.size(population)
# Out:
# 14000

# %% [markdown]
# **4. Find Size of Items of Each Array**
#
# Find size of items each array: height, weight, population
# ```
# # Expected Output:
# height.itemsize : 8
# weight.itemsize : 8
# population.itemsize : 8
# ```

# %%
height.itemsize
# Out:
# 8

# %%
weight.itemsize
# Out:
# 8

# %%
population.itemsize
# Out:
# 8

# %% [markdown]
# **4. Find Minimum Value of Each Array**
#
# Find minimum value of each array: height, weight, population
# ```
# # Expected Output:
# height.min : 1.0
# weight.min : 3.24
# population.min : 1.0
# ```

# %%
height.min()
# Out:
# 1.07

# %%
weight.min()
# Out:
# 1.13

# %%
population.min()
# Out:
# 1.07

# %% [markdown]
# **5. Find Maximum Value of Each Array**
#
# Find maximum value of each array: height, weight, population
# ```
# # Expected Output
# height.max() : 2.51
# weight.max() : 132.17
# population.max() : 132.17
# ```

# %%
height.max()
# Out:
# 2.63

# %%
weight.max()
# Out:
# 112.15

# %%
population.max()
# Out:
# 112.15

# %% [markdown]
# **6. Find Mean Value of Each Array**
#
# Find maximum value of each array: height, weight, population
# ```
# # Expected Output
# height.mean() : 1.7494871428571428
# weight.mean() : 60.41684428571429
# population.mean() : 31.083165714285716
# ```

# %%
height.mean()
# Out:
# 1.7492814285714287

# %%
weight.mean()
# Out:
# 60.21424857142857

# %%
population.mean()
# Out:
# 30.981764999999996

# %% [markdown]
# **6. Find Standard Deviation of Each Array**
#
# Find standard deviation value of each array: height, weight, population
# ```
# # Expected Output
# height.std() : 0.1981923748970856
# weight.std() : 14.821310711612284
# population.std() : 31.090684288943482
# ```

# %%
height.std()
# Out:
# 0.2009003610839798

# %%
weight.std()
# Out:
# 14.804221956916237

# %%
population.std()
# Out:
# 31.050616259684826

# %% [markdown]
# **7. Find Total value of Each Array**
#
# Find total value of each array: height, weight, population
# ```
# # Expected Output
# height.sum() : 12219.789999999999
# weight.sum() : 422009.95
# population.sum() : 434229.74
# ```

# %%
height.sum()
# Out:
# 12244.970000000001

# %%
weight.sum()
# Out:
# 421499.74

# %%
population.sum()
# Out:
# 433744.70999999996

# %% [markdown]
# **8. Create a histogram of height and weight**

# %%
plt.hist(height, label=height)
plt.hist(weight, label=weight)
# Out:
# (array([   5.,   45.,  234.,  834., 1723., 2016., 1426.,  561.,  133.,
#           23.]),
#  array([  1.13 ,  12.232,  23.334,  34.436,  45.538,  56.64 ,  67.742,
#          78.844,  89.946, 101.048, 112.15 ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# **9. Create a boxplot of height and weight**

# %%
plt.boxplot(height)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fc20be4d6d8>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fc20bde7b00>,
#   <matplotlib.lines.Line2D at 0x7fc20bde7e80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc20bdf15c0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc20bdf1240>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fc20bde7400>,
#   <matplotlib.lines.Line2D at 0x7fc20bde7780>]}

# %%
plt.boxplot(weight)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fc20bdc4908>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fc20bdd4358>,
#   <matplotlib.lines.Line2D at 0x7fc20bdd46d8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc20bdd4dd8>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc20bdd4a58>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fc20bdc4c18>,
#   <matplotlib.lines.Line2D at 0x7fc20bdc4f98>]}

# %% [markdown]
# **10. Create scatterplot of height and weight**

# %%
plt.scatter(height, weight)

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2019 Institute of Data
#
#
# ---
#
#
#
# ---
