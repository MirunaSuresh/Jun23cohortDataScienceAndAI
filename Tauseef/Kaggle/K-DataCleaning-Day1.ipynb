# %%
# Setup - Import modules
import pandas as pd
import numpy as np

# %%
# Read csv files
nfl_data = pd.read_csv("C:\\temp\\Data Science\\Kaggle\\Data Cleaning Challenge\\Day 1\\NFL Play by Play 2009-2018 (v5).csv")
sf_permits = pd.read_csv("C:\\temp\\Data Science\\Kaggle\\Data Cleaning Challenge\\Day 1\\Building_Permits.csv")

# %%
nfl_data.sample(5)
# Out:
#         play_id     game_id home_team away_team posteam posteam_type defteam  \
# 216854     2703  2013121500       ATL       WAS     ATL         home     WAS
# 10499      1204  2009100412       PIT        SD      SD         away     PIT
# 71942      1313  2010112107        NO       SEA     SEA         away      NO
# 315698     1582  2016010313       DEN        SD     DEN         home      SD
# 150800     2367  2012101800        SF       SEA      SF         home     SEA
#
#        side_of_field  yardline_100   game_date  ...  penalty_player_id  \
# 216854           WAS           2.0  2013-12-15  ...                NaN
# 10499             SD          58.0  2009-10-04  ...                NaN
# 71942            SEA          80.0  2010-11-21  ...         00-0025848
# 315698            SD          35.0  2016-01-03  ...                NaN
# 150800           SEA           1.0  2012-10-18  ...                NaN
#
#         penalty_player_name  penalty_yards replay_or_challenge  \
# ...

# %%
# Null values for first 10 columns
m_values = nfl_data.isnull().sum()
m_values[:10]
# Out:
# play_id              0
# game_id              0
# home_team            0
# away_team            0
# posteam          13242
# posteam_type     12879
# defteam          12879
# side_of_field      600
# yardline_100     13070
# game_date            0
# dtype: int64

# %%
# Missing values percentage

total_cells = np.product(nfl_data.shape)
total_m_values = m_values.sum()
(total_m_values/total_cells) * 100
# Out:
# 38.50391490571942

# %%
sf_permits.head()
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05/06/2015  0326  023            140                  NaN
# 1           04/19/2016  0306  007            440                  NaN
# 2           05/27/2016  0595  203           1647                  NaN
# 3           11/07/2016  0156  011           1230                  NaN
# 4           11/28/2016  0342  001            950                  NaN
#
#   Street Name Street Suffix  ...  Existing Construction Type  \
# 0       Ellis            St  ...                         3.0
# ...

# %%
sf_permits.shape
# Out:
# (198900, 43)

# %%
# Drop columns with missing values
sf_permits.dropna(axis = 1)
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# ...              ...          ...                               ...
# 198895       M862628            8            otc alterations permit
# 198896  201712055595            8            otc alterations permit
# 198897       M863507            8            otc alterations permit
# 198898       M863747            8            otc alterations permit
# 198899       M864287            8            otc alterations permit
#
#        Permit Creation Date Block   Lot  Street Number Street Name  \
# 0                05/06/2015  0326   023            140       Ellis
# ...

# %%
sf_permits.fillna(method = 'bfill', axis=0).fillna(0)
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# ...              ...          ...                               ...
# 198895       M862628            8            otc alterations permit
# 198896  201712055595            8            otc alterations permit
# 198897       M863507            8            otc alterations permit
# 198898       M863747            8            otc alterations permit
# 198899       M864287            8            otc alterations permit
#
#        Permit Creation Date Block   Lot  Street Number Street Number Suffix  \
# ...

# %%
sf_permits.shape
# Out:
# (198900, 43)
